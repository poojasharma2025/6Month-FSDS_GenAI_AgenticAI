# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,2  # rcparam comes from plt library where fig size width-6 height-2

import warnings
warnings.filterwarnings('ignore') # when ever os will update.ignore os error using ignore

# %% [markdown]
# ### if we got error , then pls pip install seaborn(statistic visualization advance visualization

# %%
df= pd.read_csv(r'C:\Users\WELCOME\Documents\Data Science\data.csv')
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis=sns.displot(df['InternetUsers'])

# %%
vis=sns.distplot(df['InternetUsers'])

# %%
# univariate analysis--> plot graph using 1 variable is called UA

# %%
vis=sns.distplot(df['InternetUsers'], bins=15) # bins 15 mean edges of graph

# %%
vis=sns.distplot(df['InternetUsers'], bins=20)

# %%
plt.rcParams['figure.figsize']=6,3

# %%
vis4=sns.boxplot(data = df, x='IncomeGroup', y='BirthRate')

# %% [markdown]
# ### bivarient analysis - more than one variable

# %% [markdown]
# ### outlier is a data point which is very far from other objects. it is also called anomaly detection.

# %%
vis4=sns.lmplot(data = df, x='InternetUsers', y='BirthRate') #(linear model plot

# %%
vis4=sns.lmplot(data = df, x='InternetUsers', y='BirthRate', fit_reg=False)

# %%
vis4=sns.lmplot(data = df, x='InternetUsers', y='BirthRate', fit_reg=True)

# %%
vis4=sns.lmplot(data = df, x='InternetUsers', y='BirthRate', fit_reg=False, hue='IncomeGroup')
